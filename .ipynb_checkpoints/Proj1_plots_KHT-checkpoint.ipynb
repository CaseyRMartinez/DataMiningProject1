# %%
# Set up
import os
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sbn
import scipy
import numpy as np
import lmfit
import sklearn

path = '/home/kyle/Documents/thomaskh522@gmail.com/SMU/DataMining/Project_Data/'

#show files
os.listdir(path)
# Out:
# ['FaultCode_DowntimeMapping.xlsx',
#  'tblAlarm.csv',
#  'Reference',
#  'tblGrid.csv',
#  'tblCSTurTemp.csv',
#  'PowerCurves.csv',
#  'tblStation.csv',
#  'Siemens_Fault_Code_Descriptions.xlsx',
#  'LGW_Down_Turbine_Tracker.xlsx',
#  'WTG.csv',
#  'MetTower_LGW_2017.csv',
#  'PowerCurveData.csv',
#  'tblSCTurbine.csv',
#  'Siemens Info File_V30_VS_140708_R1 00.xls',
#  'Lightning.csv',
#  'WpsHistoryDescription_V_310.pdf',
#  'MetTower_LGW_2016.csv',
#  'PFs_Pattern_March22_TQP.pdf',
#  'tblSCTurPress.csv',
#  'PartsConsumption.csv',
#  'MetTower_LGW_2018.csv',
#  'Siemens Database Tag List.xlsx',
#  'Logans Gap Component Configuration.xlsx',
#  'WPP.csv',
#  'Siemens Error Code Stop and Reset Details.xlsx',
#  'tblDailySummary.csv',
#  'Pattern Data Requirements.xlsx',
#  'TurbineModels.csv']

# %% [markdown]
# # Turbine Models
# First I wanted to understand what the turbines were like at Logan's Gap. Below is a print out of the raw data. In addition, I have used shown the descriptive statistics for the numeric data assocaited for each numeric feature

# %%
# First I want to understand turbine models
df_tubine = pd.read_csv(path + 'TurbineModels.csv')
print(df_tubine)
df_tubine.describe()
# Out:
#     WTG_Model_ID  OEM_ID   WTG_Model_Name  Rotor_Diameter_m  Blade_Length_m  \
# 0              1       1       SWT 2.3-93              93.0            45.0
# 1              2       1      SWT 2.3-101             101.0            49.0
# 2              3       1      SWT 2.3-108             108.0            53.0
# 3              4       2       MWT 95/2.4              95.0            46.2
# 4              5       3       GE 1.85-87              87.0            42.0
# 5              6       3  GE 1.5-82.5 xle              82.5            40.0
# 6              7       2        MWT 1000A              61.4            29.5
# 7              8       3      GE 2.75-120             120.0             NaN
# 8              9       3       GE 3.2-103             103.0             NaN
# 9             10       1   SWT 3.2-120 DD             120.0             NaN
# 10            11       4      G114 2.1 MW             114.0             NaN
#
#     Cut_in_Wind_Speed  Cut_out_Wind_Speed
# 0                 3.0                25.0
# 1                 3.0                25.0
# 2                 3.0                25.0
# 3                 3.5                25.0
# 4                 3.5                20.0
# 5                 3.5                20.0
# 6                 2.5                 NaN
# 7                 3.0                23.0
# 8                 3.0                25.0
# 9                 3.0                25.0
# 10                NaN                 NaN
#        WTG_Model_ID     OEM_ID  Rotor_Diameter_m  Blade_Length_m  \
# count     11.000000  11.000000         11.000000        7.000000
# mean       6.000000   2.181818         98.627273       43.528571
# std        3.316625   1.078720         17.574077        7.533639
# min        1.000000   1.000000         61.400000       29.500000
# 25%        3.500000   1.000000         90.000000       41.000000
# 50%        6.000000   2.000000        101.000000       45.000000
# 75%        8.500000   3.000000        111.000000       47.600000
# max       11.000000   4.000000        120.000000       53.000000
#
#        Cut_in_Wind_Speed  Cut_out_Wind_Speed
# count          10.000000            9.000000
# mean            3.100000           23.666667
# std             0.316228            2.179449
# min             2.500000           20.000000
# 25%             3.000000           23.000000
# 50%             3.000000           25.000000
# 75%             3.375000           25.000000
# max             3.500000           25.000000

# %% [markdown]
# # Power Curves
# ## Read in the data, and show a small subset to get an idea of the data structure

# %%
# Next lets look at the power curves
df_pc = pd.read_csv(path + 'PowerCurveData.csv')
df_pc.head()
# Out:
#    ID  Ref_Curve_ID  Wind_Speed  Active_Power_kW
# 0   1             1         0.0              0.0
# 1   2             1         0.5              0.0
# 2   3             1         1.0              0.0
# 3   4             1         1.5              0.0
# 4   5             1         2.0              0.0

# %% [markdown]
# # Power Curves
# ## Plotting Power Curves
# Below is a function that can take either a single turbine number, a list of numbers, or the string variable "all". If a single number is entered, the power curve for that reference ID is plotted. If a list of numbers are entered, then the power curve for each referenc ID is plotted. If "all" is entered then all of the power curves are plotted.

# %%
def plot_power_curve(selection):
    if selection != "all":
        if type(selection) == list:
            this = df_pc[df_pc["Ref_Curve_ID"].isin(selection)]
            sbn.pairplot(x_vars=["Wind_Speed"], y_vars=["Active_Power_kW"], data=this, size=10, hue='Ref_Curve_ID')
            plt.title("Power Curves for Power Reference Curve ID {}".format(selection), size=25)             
        else:
            this = df_pc[df_pc["Ref_Curve_ID"] == selection]
            sbn.pairplot(x_vars=["Wind_Speed"], y_vars=["Active_Power_kW"], data=this, size=10)
            plt.title("Power Curves for Power Reference Curve ID {}".format(selection), size=25)
                    
    else:
        sbn.pairplot(x_vars=["Wind_Speed"], y_vars=["Active_Power_kW"], data=df_pc, size=10, hue='Ref_Curve_ID')
        plt.title("Power Curves by Curve ID", size=25)
        
#show some power curves
plot_power_curve(18)

# %% [markdown]
# # Power Curves
# # Understanding Cutout Speed

# %%
# Based on the above we see turbine 12 powe output is 0 above 20 MPH
# lets show all turbines that make 0 kW at high windspeeds
df_cutout = df_pc[(df_pc["Wind_Speed"] > 15) & (df_pc["Active_Power_kW"] == 0)]
df_cutout
# Out:
#         ID  Ref_Curve_ID  Wind_Speed  Active_Power_kW
# 602    603            12        20.5              0.0
# 603    604            12        21.0              0.0
# 604    605            12        21.5              0.0
# 605    606            12        22.0              0.0
# 606    607            12        22.5              0.0
# 607    608            12        23.0              0.0
# 608    609            12        23.5              0.0
# 609    610            12        24.0              0.0
# 610    611            12        24.5              0.0
# 611    612            12        25.0              0.0
# 1617  1620            33        33.0              0.0
# 1684  1687            34        33.0              0.0
# 1751  1754            35        33.0              0.0
# 1818  1821            36        33.0              0.0
# 1885  1888            37        33.0              0.0
# 2069  2266            40        25.5              0.0
# 2070  2267            40        26.0              0.0
# 2071  2268            40        26.5              0.0
# 2072  2269            40        27.0              0.0
# 2073  2270            40        27.5              0.0
# 2074  2271            40        28.0              0.0
# 2075  2272            40        28.5              0.0
# 2076  2273            40        29.0              0.0
# 2077  2274            40        29.5              0.0
# 2078  2275            40        30.0              0.0

# %% [markdown]
# # Power Curves
# ## Creating an average power curve for Logan's Gap
# The data was grouped by wind speed, and then an average power curve was created using the aggregated data. Tabular and graphical output is shown below

# %%
# Now lets make an avearage for the profiles
df_windGroup = df_pc.groupby("Wind_Speed", as_index=False)
avg_power = df_windGroup.mean()
avg_power
# Out:
#     Wind_Speed           ID  Ref_Curve_ID  Active_Power_kW
# 0          0.0   976.384615     20.307692         0.000000
# 1          0.5   977.384615     20.307692         0.000000
# 2          1.0   978.384615     20.307692         0.000000
# 3          1.5   979.384615     20.307692         0.000000
# 4          2.0   980.384615     20.307692         0.000000
# 5          2.5   981.384615     20.307692         3.448718
# 6          3.0   982.384615     20.307692        26.897436
# 7          3.5   983.384615     20.307692        68.664103
# 8          4.0   984.384615     20.307692       112.174359
# 9          4.5   985.384615     20.307692       182.016667
# 10         5.0   986.384615     20.307692       252.884615
# 11         5.5   987.384615     20.307692       357.228205
# 12         6.0   988.384615     20.307692       462.853846
# 13         6.5   989.384615     20.307692       608.111538
# 14         7.0   990.384615     20.307692       754.651282
# 15         7.5   991.384615     20.307692       942.312821
# 16         8.0   992.384615     20.307692      1131.589744
# 17         8.5   993.384615     20.307692      1346.346154
# 18         9.0   994.384615     20.307692      1562.871795
# 19         9.5   995.384615     20.307692      1742.500000
# 20        10.0   996.384615     20.307692      1916.487179
# 21        10.5   997.384615     20.307692      2009.705128
# 22        11.0   998.384615     20.307692      2097.051282
# 23        11.5   999.384615     20.307692      2131.141026
# 24        12.0  1000.384615     20.307692      2162.282051
# 25        12.5  1001.384615     20.307692      2173.064103
# 26        13.0  1002.384615     20.307692      2181.923077
# 27        13.5  1003.384615     20.307692      2185.141026
# 28        14.0  1004.384615     20.307692      2187.717949
# 29        14.5  1005.384615     20.307692      2188.576923
# ..         ...          ...           ...              ...
# 37        18.5  1022.538462     20.307692      2188.525641
# 38        19.0  1023.538462     20.307692      2187.128205
# 39        19.5  1024.538462     20.307692      2187.128205
# 40        20.0  1025.538462     20.307692      2187.128205
# 41        20.5  1023.000000     20.388889      2165.777778
# 42        21.0  1024.000000     20.388889      2165.777778
# 43        21.5  1025.000000     20.388889      2165.777778
# 44        22.0  1026.000000     20.388889      2165.777778
# 45        22.5  1027.000000     20.388889      2163.944444
# 46        23.0  1028.000000     20.388889      2161.416667
# 47        23.5  1029.000000     20.388889      2158.333333
# 48        24.0  1030.000000     20.388889      2156.250000
# 49        24.5  1031.000000     20.388889      2136.319444
# 50        25.0  1032.000000     20.388889      2113.666667
# 51        25.5  1896.375000     36.500000      1983.625000
# 52        26.0  1897.375000     36.500000      1851.375000
# 53        26.5  1898.375000     36.500000      1719.187500
# 54        27.0  1899.375000     36.500000      1587.000000
# 55        27.5  1900.375000     36.500000      1454.812500
# 56        28.0  1901.375000     36.500000      1322.625000
# 57        28.5  1902.375000     36.500000      1190.250000
# 58        29.0  1903.375000     36.500000      1057.875000
# 59        29.5  1904.375000     36.500000       925.687500
# 60        30.0  1905.375000     36.500000       793.500000
# 61        30.5  1853.571429     36.000000       755.785714
# 62        31.0  1854.571429     36.000000       604.714286
# 63        31.5  1855.571429     36.000000       453.571429
# 64        32.0  1856.571429     36.000000       302.428571
# 65        32.5  1857.571429     36.000000       151.214286
# 66        33.0  1754.000000     35.000000         0.000000
#
# [67 rows x 4 columns]

# %%
sbn.pairplot(x_vars=["Wind_Speed"], y_vars=["Active_Power_kW"], data=avg_power, size=10)
plt.title("Average Power Curve for all Turbines", size=25)
# Out:
# Text(0.5,1,'Average Power Curve for all Turbines')

# %% [markdown]
# # Fitting a curve to Reference ID Curve 18

# %%
ref = df_pc[df_pc["Ref_Curve_ID"] == 18]
plt.plot(ref['Wind_Speed'], ref['Active_Power_kW'])

# %% [markdown]
# # Moving Forward
# The previous data set did not meet the complexity requirements, however, there was still very valuable information in that dataset. We can use the power curve information to compare turbine opeartion to its theoretical operation. Next I will look at one or two other data sets that meet the complexity requrements.
#
# ## Investigation of tblSCTurbine.csv
# This dataset is over 4 GB in size. It cannot be read into memory on my machine. To start, I will only read in 100,000 lines of data to get an idea of the underlying structure. We may move to a spark installation so that we can handle such a large ammount of data.

# %%
df_main = pd.read_csv(path + "tblSCTurbine.csv", nrows=100000)
df_main.head()
# Out:
#    Name                TimeStamp     wtc_CurTime_endvalue  wtc_SecAnemo_mean  \
# 0  T010  2015-05-19 23:00:00.000  2015-05-19 22:59:56.000           8.026840
# 1  T010  2015-05-19 23:10:00.000  2015-05-19 23:09:56.000           8.709124
# 2  T010  2015-05-19 23:20:00.000  2015-05-19 23:19:56.000          10.432920
# 3  T010  2015-05-19 23:30:00.000  2015-05-19 23:29:56.000           8.176679
# 4  T010  2015-05-19 23:40:00.000  2015-05-19 23:39:56.000           8.793220
#
#    wtc_YawPos_mean  wtc_GenRpm_mean  wtc_HubLubGr_mean  wtc_IceDetec_mean  \
# 0         40.70000              0.6                NaN                NaN
# 1         12.69578              0.6                NaN                NaN
# 2        311.68360              0.6                NaN                NaN
# 3        164.15750              0.6                NaN                NaN
# 4        151.80000              0.6                NaN                NaN
#
#    wtc_IMidBa_mean  wtc_IMidCa_mean        ...          wtc_ReactRef_endvalue  \
# 0              NaN              NaN        ...                            NaN
# 1              NaN              NaN        ...                            NaN
# 2              NaN              NaN        ...                            NaN
# 3              NaN              NaN        ...                            NaN
# 4              NaN              NaN        ...                            NaN
#
#    wtc_ScYawPos_mean  wtc_PrWindSp_mean  wtc_SeWindSp_mean  wtc_AcWindSp_mean  \
# 0           40.70000           9.485412           8.017353           9.485392
# 1           10.96358           8.437153           8.697805           8.437179
# 2           68.03295          10.836880          10.431380          10.836890
# 3         -194.58410           9.402458           8.174048           9.402458
# 4         -208.20000           9.098410           8.795180           9.098390
#
#    wtc_NacelPos_mean  wtc_TetAnemo_mean  wtc_TetAnFrq_mean  \
# 0           40.70000                NaN               0.01
# 1           12.70296                NaN               0.01
# 2          311.68570                NaN               0.01
# 3          164.16360                NaN               0.01
# 4          151.80000                NaN               0.01
#
#    wtc_TowerFrq_Frequenc_mean  wtc_BoostAva_mean
# 0                      0.2004                0.0
# 1                      0.2004                0.0
# 2                      0.2004                0.0
# 3                      0.2004                0.0
# 4                      0.2004                0.0
#
# [5 rows x 41 columns]

# %%
#How many unique turbines are there? 37 
df_main['Name'].unique()
# Out:
# array(['T010', 'T006', 'T007', 'T011', 'T013', 'T008', 'T009', 'T019',
#        'T012', 'T014', 'T017', 'T001', 'T002', 'T003', 'T004', 'T015',
#        'T018', 'T016', 'T005', 'T020', 'T039', 'T040', 'T041', 'T049',
#        'T050', 'T054', 'T021', 'T052', 'T023'], dtype=object)

# %% [markdown]
# # Comparing Power Output to Modeled Values and Wind Speeds
# Below are some graphs that plot wind speed versus power output (shown as blue dots). Modeled/Design data is shown as the red line. There appear to be some problematic data points (for example, high power output when the wind speed is very low). I would think that these values are not possible.

# %%
# What are the columns
by_turbine = df_main.groupby('Name')

for name, group in by_turbine:
    plt.plot(ref['Wind_Speed'], ref['Active_Power_kW'], 'r-', label='Model')
    plt.scatter(group['wtc_PrWindSp_mean'], group['wtc_PowerRef_endvalue'], label=name)
    plt.title("Wind Speed vs Power for Turbine " + str(name))
    plt.legend()
    plt.show()

# %% [markdown]
# # Investigation of unusual data for turbines
# There are some power outputs that are unusually high based on wind speed. These values need to be investigated to ensure that data is valid and should be included in the plots.

# %%
t001 = df_main[df_main['Name'] == 'T001']
by_wind = t001.groupby('wtc_PrWindSp_mean')
plt.hist(t001['wtc_PrWindSp_mean'], bins=20)
plt.title("Histogram of Wind Speeds at Turbine 001")
plt.xlabel("Wind Speed")
plt.grid(True)

# %%
t001 = df_main[df_main['Name'] == 'T001']
plt.hist(t001['wtc_PowerRef_endvalue'], bins=5)
plt.title("Histogram of kW Output at Turbine 001")
plt.xlabel("Wind Speed")
plt.grid(True)

# %% [markdown]
# # Bad data - Power reference is bad, Wind speed is correct, time stamps are sequential

# %%
cols = ['wtc_PowerRef_endvalue', 'wtc_PrWindSp_mean', 'TimeStamp']
t001[(t001['wtc_PowerRef_endvalue'] > 400) & (t001['wtc_PowerRef_endvalue'] <1000)][cols]
# Out:
#        wtc_PowerRef_endvalue  wtc_PrWindSp_mean                TimeStamp
# 17076                  700.0           4.870248  2015-06-11 00:00:00.000
# 17093                  700.0           5.611313  2015-06-11 00:10:00.000
# 17110                  700.0           4.852515  2015-06-11 00:20:00.000
# 17127                  700.0           4.644242  2015-06-11 00:30:00.000
# 17144                  700.0           4.474222  2015-06-11 00:40:00.000
# 17161                  700.0           4.432990  2015-06-11 00:50:00.000
# 17178                  700.0           4.824564  2015-06-11 01:00:00.000
# 17195                  700.0           5.453146  2015-06-11 01:10:00.000
# 17212                  700.0           6.343184  2015-06-11 01:20:00.000
# 17229                  700.0           6.113025  2015-06-11 01:30:00.000
# 17246                  700.0           4.716383  2015-06-11 01:40:00.000
# 17263                  700.0           5.582972  2015-06-11 01:50:00.000
# 17280                  700.0           4.917248  2015-06-11 02:00:00.000
# 17297                  700.0           6.006183  2015-06-11 02:10:00.000
# 17314                  700.0           5.651220  2015-06-11 02:20:00.000
# 17331                  700.0           6.700510  2015-06-11 02:30:00.000
# 17348                  700.0           7.268668  2015-06-11 02:40:00.000
# 17365                  700.0           6.192217  2015-06-11 02:50:00.000
# 17382                  700.0           7.249887  2015-06-11 03:00:00.000
# 17399                  700.0           7.185200  2015-06-11 03:10:00.000
# 17416                  700.0           6.743582  2015-06-11 03:20:00.000
# 17433                  700.0           6.121716  2015-06-11 03:30:00.000
# 17450                  700.0           6.355183  2015-06-11 03:40:00.000
# 17467                  700.0           6.174218  2015-06-11 03:50:00.000
# 17484                  700.0           5.171550  2015-06-11 04:00:00.000
# 17501                  700.0           5.122334  2015-06-11 04:10:00.000
# 17518                  700.0           4.926175  2015-06-11 04:20:00.000
# 17535                  700.0           5.934662  2015-06-11 04:30:00.000
# 17552                  700.0           6.448175  2015-06-11 04:40:00.000
# 17569                  700.0           6.514487  2015-06-11 04:50:00.000
# ...                      ...                ...                      ...
# 57862                  789.0           5.989200  2015-06-28 03:50:00.000
# 57906                  702.0           6.246485  2015-06-28 04:10:00.000
# 57950                  504.0           6.655918  2015-06-28 04:30:00.000
# 58258                  760.0           5.504960  2015-06-28 06:50:00.000
# 63100                  482.0           5.400183  2015-06-29 18:40:00.000
# 63880                  839.0           7.698212  2015-06-30 00:10:00.000
# 64456                  770.0           4.589182  2015-06-30 04:10:00.000
# 64624                  404.0           5.355687  2015-06-30 05:20:00.000
# 67298                  790.0           8.512555  2015-07-01 00:00:00.000
# 69620                  994.0           7.381659  2015-07-01 16:10:00.000
# 69692                  652.0           7.475062  2015-07-01 16:40:00.000
# 69740                  532.0           5.706810  2015-07-01 17:00:00.000
# 74916                  699.0           7.919152  2015-07-03 05:00:00.000
# 76854                  799.0           4.327382  2015-07-03 18:30:00.000
# 79374                  507.0           4.527732  2015-07-04 12:00:00.000
# 80406                  710.0           6.387338  2015-07-04 19:10:00.000
# 80550                  964.0           8.607502  2015-07-04 20:10:00.000
# 83152                  515.0           9.894511  2015-07-05 13:40:00.000
# 91620                  501.0           5.980348  2015-07-07 18:50:00.000
# 91707                  979.0           6.400265  2015-07-07 19:20:00.000
# 91997                  572.0           5.756797  2015-07-07 21:00:00.000
# 92113                  901.0           3.805212  2015-07-07 21:40:00.000
# 92635                  755.0           5.918995  2015-07-08 00:40:00.000
# 92809                  555.0           5.777098  2015-07-08 01:40:00.000
# 93969                  890.0           3.312937  2015-07-08 08:20:00.000
# 93998                  890.0           1.455860  2015-07-08 08:30:00.000
# 94085                  764.0           4.541063  2015-07-08 09:00:00.000
# 94375                  669.0           6.398805  2015-07-08 10:40:00.000
# 95042                  868.0           3.842487  2015-07-08 14:30:00.000
# 95709                  939.0           5.536268  2015-07-08 18:20:00.000
#
# [836 rows x 3 columns]

# %%
# Lets see how some of this data correlated
df_main.corr()
#There is a lot of NA data. I will drop columns with NA to see what happens.
# Out:
#                             wtc_SecAnemo_mean  wtc_YawPos_mean  \
# wtc_SecAnemo_mean                1.000000e+00    -8.272123e-02
# wtc_YawPos_mean                 -8.272123e-02     1.000000e+00
# wtc_GenRpm_mean                  4.986059e-01     5.386099e-02
# wtc_HubLubGr_mean                         NaN              NaN
# wtc_IceDetec_mean                         NaN              NaN
# wtc_IMidBa_mean                           NaN              NaN
# wtc_IMidCa_mean                           NaN              NaN
# wtc_IMidAa_mean                           NaN              NaN
# wtc_MainSRpm_mean                4.986290e-01     5.384951e-02
# wtc_PitchRef_mean                         NaN              NaN
# wtc_PitchRef_BladeA_mean        -3.214121e-01    -6.278624e-02
# wtc_PitchRef_BladeB_mean        -3.214633e-01    -6.279503e-02
# wtc_PitchRef_BladeC_mean        -3.213466e-01    -6.267047e-02
# wtc_PitcRefA_mean               -3.213378e-01    -6.270079e-02
# wtc_PriAnemo_mean                2.565433e-02     5.666356e-02
# wtc_PWMBa_mean                            NaN              NaN
# wtc_PWMCa_mean                            NaN              NaN
# wtc_PWMAa_mean                            NaN              NaN
# wtc_HubAnIn5_mean                         NaN              NaN
# wtc_HubAnIn6_mean                         NaN              NaN
# wtc_HubAnIn7_mean                         NaN              NaN
# wtc_NacHumid_mean                         NaN              NaN
# wtc_TwrHumid_mean               -7.481548e-02     1.719556e-02
# wtc_VisMeter_endvalue                     NaN              NaN
# wtc_PitcPosA_mean               -3.215894e-01    -6.256296e-02
# wtc_PitcPosB_mean               -3.173661e-01    -6.082893e-02
# wtc_PitcPosC_mean               -3.206822e-01    -6.343391e-02
# wtc_PowerRef_endvalue            1.173002e-01     8.451365e-02
# wtc_ReactRef_endvalue                     NaN              NaN
# wtc_ScYawPos_mean                8.154370e-02     1.085599e-01
# wtc_PrWindSp_mean                7.668186e-01    -4.581449e-03
# wtc_SeWindSp_mean                9.999979e-01    -8.271703e-02
# wtc_AcWindSp_mean                8.373585e-01     3.120802e-03
# wtc_NacelPos_mean               -8.270651e-02     9.999331e-01
# wtc_TetAnemo_mean                         NaN              NaN
# wtc_TetAnFrq_mean                1.502009e-14    -2.586316e-14
# wtc_TowerFrq_Frequenc_mean       1.478245e-01    -6.771574e-02
# wtc_BoostAva_mean                9.901547e-02     5.862956e-03
#
#                             wtc_GenRpm_mean  wtc_HubLubGr_mean  \
# wtc_SecAnemo_mean              4.986059e-01                NaN
# wtc_YawPos_mean                5.386099e-02                NaN
# wtc_GenRpm_mean                1.000000e+00                NaN
# wtc_HubLubGr_mean                       NaN                NaN
# wtc_IceDetec_mean                       NaN                NaN
# wtc_IMidBa_mean                         NaN                NaN
# wtc_IMidCa_mean                         NaN                NaN
# wtc_IMidAa_mean                         NaN                NaN
# wtc_MainSRpm_mean              9.999973e-01                NaN
# wtc_PitchRef_mean                       NaN                NaN
# wtc_PitchRef_BladeA_mean      -9.287173e-01                NaN
# wtc_PitchRef_BladeB_mean      -9.287777e-01                NaN
# wtc_PitchRef_BladeC_mean      -9.286980e-01                NaN
# wtc_PitcRefA_mean             -9.286824e-01                NaN
# wtc_PriAnemo_mean              3.844356e-02                NaN
# wtc_PWMBa_mean                          NaN                NaN
# wtc_PWMCa_mean                          NaN                NaN
# wtc_PWMAa_mean                          NaN                NaN
# wtc_HubAnIn5_mean                       NaN                NaN
# wtc_HubAnIn6_mean                       NaN                NaN
# wtc_HubAnIn7_mean                       NaN                NaN
# wtc_NacHumid_mean                       NaN                NaN
# wtc_TwrHumid_mean             -3.054680e-01                NaN
# wtc_VisMeter_endvalue                   NaN                NaN
# wtc_PitcPosA_mean             -9.287257e-01                NaN
# wtc_PitcPosB_mean             -8.735227e-01                NaN
# wtc_PitcPosC_mean             -9.288277e-01                NaN
# wtc_PowerRef_endvalue          1.267053e-01                NaN
# wtc_ReactRef_endvalue                   NaN                NaN
# wtc_ScYawPos_mean              1.036879e-01                NaN
# wtc_PrWindSp_mean              5.699439e-01                NaN
# wtc_SeWindSp_mean              4.986140e-01                NaN
# wtc_AcWindSp_mean              5.638399e-01                NaN
# wtc_NacelPos_mean              5.385389e-02                NaN
# wtc_TetAnemo_mean                       NaN                NaN
# wtc_TetAnFrq_mean             -8.762689e-14                NaN
# wtc_TowerFrq_Frequenc_mean     3.247868e-01                NaN
# wtc_BoostAva_mean              7.692995e-02                NaN
#
#                             wtc_IceDetec_mean  wtc_IMidBa_mean  \
# wtc_SecAnemo_mean                         NaN              NaN
# wtc_YawPos_mean                           NaN              NaN
# wtc_GenRpm_mean                           NaN              NaN
# wtc_HubLubGr_mean                         NaN              NaN
# wtc_IceDetec_mean                         NaN              NaN
# wtc_IMidBa_mean                           NaN              NaN
# wtc_IMidCa_mean                           NaN              NaN
# wtc_IMidAa_mean                           NaN              NaN
# wtc_MainSRpm_mean                         NaN              NaN
# wtc_PitchRef_mean                         NaN              NaN
# wtc_PitchRef_BladeA_mean                  NaN              NaN
# wtc_PitchRef_BladeB_mean                  NaN              NaN
# wtc_PitchRef_BladeC_mean                  NaN              NaN
# wtc_PitcRefA_mean                         NaN              NaN
# wtc_PriAnemo_mean                         NaN              NaN
# wtc_PWMBa_mean                            NaN              NaN
# wtc_PWMCa_mean                            NaN              NaN
# wtc_PWMAa_mean                            NaN              NaN
# wtc_HubAnIn5_mean                         NaN              NaN
# wtc_HubAnIn6_mean                         NaN              NaN
# wtc_HubAnIn7_mean                         NaN              NaN
# wtc_NacHumid_mean                         NaN              NaN
# wtc_TwrHumid_mean                         NaN              NaN
# wtc_VisMeter_endvalue                     NaN              NaN
# wtc_PitcPosA_mean                         NaN              NaN
# wtc_PitcPosB_mean                         NaN              NaN
# wtc_PitcPosC_mean                         NaN              NaN
# wtc_PowerRef_endvalue                     NaN              NaN
# wtc_ReactRef_endvalue                     NaN              NaN
# wtc_ScYawPos_mean                         NaN              NaN
# wtc_PrWindSp_mean                         NaN              NaN
# wtc_SeWindSp_mean                         NaN              NaN
# wtc_AcWindSp_mean                         NaN              NaN
# wtc_NacelPos_mean                         NaN              NaN
# wtc_TetAnemo_mean                         NaN              NaN
# wtc_TetAnFrq_mean                         NaN              NaN
# wtc_TowerFrq_Frequenc_mean                NaN              NaN
# wtc_BoostAva_mean                         NaN              NaN
#
#                             wtc_IMidCa_mean  wtc_IMidAa_mean  \
# wtc_SecAnemo_mean                       NaN              NaN
# wtc_YawPos_mean                         NaN              NaN
# wtc_GenRpm_mean                         NaN              NaN
# wtc_HubLubGr_mean                       NaN              NaN
# wtc_IceDetec_mean                       NaN              NaN
# wtc_IMidBa_mean                         NaN              NaN
# wtc_IMidCa_mean                         NaN              NaN
# wtc_IMidAa_mean                         NaN              NaN
# wtc_MainSRpm_mean                       NaN              NaN
# wtc_PitchRef_mean                       NaN              NaN
# wtc_PitchRef_BladeA_mean                NaN              NaN
# wtc_PitchRef_BladeB_mean                NaN              NaN
# wtc_PitchRef_BladeC_mean                NaN              NaN
# wtc_PitcRefA_mean                       NaN              NaN
# wtc_PriAnemo_mean                       NaN              NaN
# wtc_PWMBa_mean                          NaN              NaN
# wtc_PWMCa_mean                          NaN              NaN
# wtc_PWMAa_mean                          NaN              NaN
# wtc_HubAnIn5_mean                       NaN              NaN
# wtc_HubAnIn6_mean                       NaN              NaN
# wtc_HubAnIn7_mean                       NaN              NaN
# wtc_NacHumid_mean                       NaN              NaN
# wtc_TwrHumid_mean                       NaN              NaN
# wtc_VisMeter_endvalue                   NaN              NaN
# wtc_PitcPosA_mean                       NaN              NaN
# wtc_PitcPosB_mean                       NaN              NaN
# wtc_PitcPosC_mean                       NaN              NaN
# wtc_PowerRef_endvalue                   NaN              NaN
# wtc_ReactRef_endvalue                   NaN              NaN
# wtc_ScYawPos_mean                       NaN              NaN
# wtc_PrWindSp_mean                       NaN              NaN
# wtc_SeWindSp_mean                       NaN              NaN
# wtc_AcWindSp_mean                       NaN              NaN
# wtc_NacelPos_mean                       NaN              NaN
# wtc_TetAnemo_mean                       NaN              NaN
# wtc_TetAnFrq_mean                       NaN              NaN
# wtc_TowerFrq_Frequenc_mean              NaN              NaN
# wtc_BoostAva_mean                       NaN              NaN
#
#                             wtc_MainSRpm_mean  wtc_PitchRef_mean  \
# wtc_SecAnemo_mean                4.986290e-01                NaN
# wtc_YawPos_mean                  5.384951e-02                NaN
# wtc_GenRpm_mean                  9.999973e-01                NaN
# wtc_HubLubGr_mean                         NaN                NaN
# wtc_IceDetec_mean                         NaN                NaN
# wtc_IMidBa_mean                           NaN                NaN
# wtc_IMidCa_mean                           NaN                NaN
# wtc_IMidAa_mean                           NaN                NaN
# wtc_MainSRpm_mean                1.000000e+00                NaN
# wtc_PitchRef_mean                         NaN                NaN
# wtc_PitchRef_BladeA_mean        -9.287164e-01                NaN
# wtc_PitchRef_BladeB_mean        -9.287769e-01                NaN
# wtc_PitchRef_BladeC_mean        -9.286971e-01                NaN
# wtc_PitcRefA_mean               -9.286813e-01                NaN
# wtc_PriAnemo_mean                3.844302e-02                NaN
# wtc_PWMBa_mean                            NaN                NaN
# wtc_PWMCa_mean                            NaN                NaN
# wtc_PWMAa_mean                            NaN                NaN
# wtc_HubAnIn5_mean                         NaN                NaN
# wtc_HubAnIn6_mean                         NaN                NaN
# wtc_HubAnIn7_mean                         NaN                NaN
# wtc_NacHumid_mean                         NaN                NaN
# wtc_TwrHumid_mean               -3.054802e-01                NaN
# wtc_VisMeter_endvalue                     NaN                NaN
# wtc_PitcPosA_mean               -9.287266e-01                NaN
# wtc_PitcPosB_mean               -8.735084e-01                NaN
# wtc_PitcPosC_mean               -9.288288e-01                NaN
# wtc_PowerRef_endvalue            1.266859e-01                NaN
# wtc_ReactRef_endvalue                     NaN                NaN
# wtc_ScYawPos_mean                1.036544e-01                NaN
# wtc_PrWindSp_mean                5.699597e-01                NaN
# wtc_SeWindSp_mean                4.986371e-01                NaN
# wtc_AcWindSp_mean                5.638593e-01                NaN
# wtc_NacelPos_mean                5.384265e-02                NaN
# wtc_TetAnemo_mean                         NaN                NaN
# wtc_TetAnFrq_mean                4.543671e-14                NaN
# wtc_TowerFrq_Frequenc_mean       3.249945e-01                NaN
# wtc_BoostAva_mean                7.692752e-02                NaN
#
#                                   ...          wtc_ReactRef_endvalue  \
# wtc_SecAnemo_mean                 ...                            NaN
# wtc_YawPos_mean                   ...                            NaN
# wtc_GenRpm_mean                   ...                            NaN
# wtc_HubLubGr_mean                 ...                            NaN
# wtc_IceDetec_mean                 ...                            NaN
# wtc_IMidBa_mean                   ...                            NaN
# wtc_IMidCa_mean                   ...                            NaN
# wtc_IMidAa_mean                   ...                            NaN
# wtc_MainSRpm_mean                 ...                            NaN
# wtc_PitchRef_mean                 ...                            NaN
# wtc_PitchRef_BladeA_mean          ...                            NaN
# wtc_PitchRef_BladeB_mean          ...                            NaN
# wtc_PitchRef_BladeC_mean          ...                            NaN
# wtc_PitcRefA_mean                 ...                            NaN
# wtc_PriAnemo_mean                 ...                            NaN
# wtc_PWMBa_mean                    ...                            NaN
# wtc_PWMCa_mean                    ...                            NaN
# wtc_PWMAa_mean                    ...                            NaN
# wtc_HubAnIn5_mean                 ...                            NaN
# wtc_HubAnIn6_mean                 ...                            NaN
# wtc_HubAnIn7_mean                 ...                            NaN
# wtc_NacHumid_mean                 ...                            NaN
# wtc_TwrHumid_mean                 ...                            NaN
# wtc_VisMeter_endvalue             ...                            NaN
# wtc_PitcPosA_mean                 ...                            NaN
# wtc_PitcPosB_mean                 ...                            NaN
# wtc_PitcPosC_mean                 ...                            NaN
# wtc_PowerRef_endvalue             ...                            NaN
# wtc_ReactRef_endvalue             ...                            NaN
# wtc_ScYawPos_mean                 ...                            NaN
# wtc_PrWindSp_mean                 ...                            NaN
# wtc_SeWindSp_mean                 ...                            NaN
# wtc_AcWindSp_mean                 ...                            NaN
# wtc_NacelPos_mean                 ...                            NaN
# wtc_TetAnemo_mean                 ...                            NaN
# wtc_TetAnFrq_mean                 ...                            NaN
# wtc_TowerFrq_Frequenc_mean        ...                            NaN
# wtc_BoostAva_mean                 ...                            NaN
#
#                             wtc_ScYawPos_mean  wtc_PrWindSp_mean  \
# wtc_SecAnemo_mean                8.154370e-02       7.668186e-01
# wtc_YawPos_mean                  1.085599e-01      -4.581449e-03
# wtc_GenRpm_mean                  1.036879e-01       5.699439e-01
# wtc_HubLubGr_mean                         NaN                NaN
# wtc_IceDetec_mean                         NaN                NaN
# wtc_IMidBa_mean                           NaN                NaN
# wtc_IMidCa_mean                           NaN                NaN
# wtc_IMidAa_mean                           NaN                NaN
# wtc_MainSRpm_mean                1.036544e-01       5.699597e-01
# wtc_PitchRef_mean                         NaN                NaN
# wtc_PitchRef_BladeA_mean        -1.219151e-01      -3.766912e-01
# wtc_PitchRef_BladeB_mean        -1.218319e-01      -3.767870e-01
# wtc_PitchRef_BladeC_mean        -1.219356e-01      -3.766380e-01
# wtc_PitcRefA_mean               -1.219018e-01      -3.766284e-01
# wtc_PriAnemo_mean               -3.894834e-02       1.959673e-02
# wtc_PWMBa_mean                            NaN                NaN
# wtc_PWMCa_mean                            NaN                NaN
# wtc_PWMAa_mean                            NaN                NaN
# wtc_HubAnIn5_mean                         NaN                NaN
# wtc_HubAnIn6_mean                         NaN                NaN
# wtc_HubAnIn7_mean                         NaN                NaN
# wtc_NacHumid_mean                         NaN                NaN
# wtc_TwrHumid_mean                2.756473e-02      -1.039706e-01
# wtc_VisMeter_endvalue                     NaN                NaN
# wtc_PitcPosA_mean               -1.205761e-01      -3.767378e-01
# wtc_PitcPosB_mean               -7.102515e-02      -3.669303e-01
# wtc_PitcPosC_mean               -1.214683e-01      -3.760417e-01
# wtc_PowerRef_endvalue            4.306838e-03       9.727562e-02
# wtc_ReactRef_endvalue                     NaN                NaN
# wtc_ScYawPos_mean                1.000000e+00      -2.583808e-02
# wtc_PrWindSp_mean               -2.583808e-02       1.000000e+00
# wtc_SeWindSp_mean                8.154788e-02       7.668160e-01
# wtc_AcWindSp_mean               -1.028831e-02       9.345178e-01
# wtc_NacelPos_mean                1.099904e-01      -4.591876e-03
# wtc_TetAnemo_mean                         NaN                NaN
# wtc_TetAnFrq_mean               -9.821085e-15       1.726511e-14
# wtc_TowerFrq_Frequenc_mean      -1.013946e-02       1.700929e-01
# wtc_BoostAva_mean                2.192029e-02       1.077078e-01
#
#                             wtc_SeWindSp_mean  wtc_AcWindSp_mean  \
# wtc_SecAnemo_mean                9.999979e-01       8.373585e-01
# wtc_YawPos_mean                 -8.271703e-02       3.120802e-03
# wtc_GenRpm_mean                  4.986140e-01       5.638399e-01
# wtc_HubLubGr_mean                         NaN                NaN
# wtc_IceDetec_mean                         NaN                NaN
# wtc_IMidBa_mean                           NaN                NaN
# wtc_IMidCa_mean                           NaN                NaN
# wtc_IMidAa_mean                           NaN                NaN
# wtc_MainSRpm_mean                4.986371e-01       5.638593e-01
# wtc_PitchRef_mean                         NaN                NaN
# wtc_PitchRef_BladeA_mean        -3.214197e-01      -3.568595e-01
# wtc_PitchRef_BladeB_mean        -3.214708e-01      -3.569437e-01
# wtc_PitchRef_BladeC_mean        -3.213541e-01      -3.568068e-01
# wtc_PitcRefA_mean               -3.213454e-01      -3.568094e-01
# wtc_PriAnemo_mean                2.566576e-02       1.814505e-02
# wtc_PWMBa_mean                            NaN                NaN
# wtc_PWMCa_mean                            NaN                NaN
# wtc_PWMAa_mean                            NaN                NaN
# wtc_HubAnIn5_mean                         NaN                NaN
# wtc_HubAnIn6_mean                         NaN                NaN
# wtc_HubAnIn7_mean                         NaN                NaN
# wtc_NacHumid_mean                         NaN                NaN
# wtc_TwrHumid_mean               -7.481138e-02      -8.984321e-02
# wtc_VisMeter_endvalue                     NaN                NaN
# wtc_PitcPosA_mean               -3.215970e-01      -3.568797e-01
# wtc_PitcPosB_mean               -3.173733e-01      -3.465947e-01
# wtc_PitcPosC_mean               -3.206899e-01      -3.564104e-01
# wtc_PowerRef_endvalue            1.173085e-01       1.145012e-01
# wtc_ReactRef_endvalue                     NaN                NaN
# wtc_ScYawPos_mean                8.154788e-02      -1.028831e-02
# wtc_PrWindSp_mean                7.668160e-01       9.345178e-01
# wtc_SeWindSp_mean                1.000000e+00       8.373575e-01
# wtc_AcWindSp_mean                8.373575e-01       1.000000e+00
# wtc_NacelPos_mean               -8.270238e-02       3.134145e-03
# wtc_TetAnemo_mean                         NaN                NaN
# wtc_TetAnFrq_mean                3.280933e-15       2.000542e-14
# wtc_TowerFrq_Frequenc_mean       1.478263e-01       1.440394e-01
# wtc_BoostAva_mean                9.902938e-02       1.089651e-01
#
#                             wtc_NacelPos_mean  wtc_TetAnemo_mean  \
# wtc_SecAnemo_mean               -8.270651e-02                NaN
# wtc_YawPos_mean                  9.999331e-01                NaN
# wtc_GenRpm_mean                  5.385389e-02                NaN
# wtc_HubLubGr_mean                         NaN                NaN
# wtc_IceDetec_mean                         NaN                NaN
# wtc_IMidBa_mean                           NaN                NaN
# wtc_IMidCa_mean                           NaN                NaN
# wtc_IMidAa_mean                           NaN                NaN
# wtc_MainSRpm_mean                5.384265e-02                NaN
# wtc_PitchRef_mean                         NaN                NaN
# wtc_PitchRef_BladeA_mean        -6.277956e-02                NaN
# wtc_PitchRef_BladeB_mean        -6.278835e-02                NaN
# wtc_PitchRef_BladeC_mean        -6.266380e-02                NaN
# wtc_PitcRefA_mean               -6.269386e-02                NaN
# wtc_PriAnemo_mean                5.665758e-02                NaN
# wtc_PWMBa_mean                            NaN                NaN
# wtc_PWMCa_mean                            NaN                NaN
# wtc_PWMAa_mean                            NaN                NaN
# wtc_HubAnIn5_mean                         NaN                NaN
# wtc_HubAnIn6_mean                         NaN                NaN
# wtc_HubAnIn7_mean                         NaN                NaN
# wtc_NacHumid_mean                         NaN                NaN
# wtc_TwrHumid_mean                1.723492e-02                NaN
# wtc_VisMeter_endvalue                     NaN                NaN
# wtc_PitcPosA_mean               -6.255642e-02                NaN
# wtc_PitcPosB_mean               -6.082265e-02                NaN
# wtc_PitcPosC_mean               -6.342739e-02                NaN
# wtc_PowerRef_endvalue            8.834001e-02                NaN
# wtc_ReactRef_endvalue                     NaN                NaN
# wtc_ScYawPos_mean                1.099904e-01                NaN
# wtc_PrWindSp_mean               -4.591876e-03                NaN
# wtc_SeWindSp_mean               -8.270238e-02                NaN
# wtc_AcWindSp_mean                3.134145e-03                NaN
# wtc_NacelPos_mean                1.000000e+00                NaN
# wtc_TetAnemo_mean                         NaN                NaN
# wtc_TetAnFrq_mean               -2.407722e-14                NaN
# wtc_TowerFrq_Frequenc_mean      -6.774504e-02                NaN
# wtc_BoostAva_mean                5.862269e-03                NaN
#
#                             wtc_TetAnFrq_mean  wtc_TowerFrq_Frequenc_mean  \
# wtc_SecAnemo_mean                1.502009e-14                1.478245e-01
# wtc_YawPos_mean                 -2.586316e-14               -6.771574e-02
# wtc_GenRpm_mean                 -8.762689e-14                3.247868e-01
# wtc_HubLubGr_mean                         NaN                         NaN
# wtc_IceDetec_mean                         NaN                         NaN
# wtc_IMidBa_mean                           NaN                         NaN
# wtc_IMidCa_mean                           NaN                         NaN
# wtc_IMidAa_mean                           NaN                         NaN
# wtc_MainSRpm_mean                4.543671e-14                3.249945e-01
# wtc_PitchRef_mean                         NaN                         NaN
# wtc_PitchRef_BladeA_mean        -3.284393e-13               -3.432797e-01
# wtc_PitchRef_BladeB_mean        -2.059883e-13               -3.433273e-01
# wtc_PitchRef_BladeC_mean         4.251748e-13               -3.430735e-01
# wtc_PitcRefA_mean               -1.753598e-13               -3.426573e-01
# wtc_PriAnemo_mean                3.233177e-10                1.303757e-02
# wtc_PWMBa_mean                            NaN                         NaN
# wtc_PWMCa_mean                            NaN                         NaN
# wtc_PWMAa_mean                            NaN                         NaN
# wtc_HubAnIn5_mean                         NaN                         NaN
# wtc_HubAnIn6_mean                         NaN                         NaN
# wtc_HubAnIn7_mean                         NaN                         NaN
# wtc_NacHumid_mean                         NaN                         NaN
# wtc_TwrHumid_mean                1.211987e-15               -1.007655e-01
# wtc_VisMeter_endvalue                     NaN                         NaN
# wtc_PitcPosA_mean               -7.325301e-15               -3.423335e-01
# wtc_PitcPosB_mean               -4.443142e-14               -2.611274e-01
# wtc_PitcPosC_mean               -4.299286e-14               -3.426959e-01
# wtc_PowerRef_endvalue           -2.405534e-13               -2.015335e-02
# wtc_ReactRef_endvalue                     NaN                         NaN
# wtc_ScYawPos_mean               -9.821085e-15               -1.013946e-02
# wtc_PrWindSp_mean                1.726511e-14                1.700929e-01
# wtc_SeWindSp_mean                3.280933e-15                1.478263e-01
# wtc_AcWindSp_mean                2.000542e-14                1.440394e-01
# wtc_NacelPos_mean               -2.407722e-14               -6.774504e-02
# wtc_TetAnemo_mean                         NaN                         NaN
# wtc_TetAnFrq_mean                1.000000e+00               -8.371888e-12
# wtc_TowerFrq_Frequenc_mean      -8.371888e-12                1.000000e+00
# wtc_BoostAva_mean               -1.433139e-14                1.919346e-02
#
#                             wtc_BoostAva_mean
# wtc_SecAnemo_mean                9.901547e-02
# wtc_YawPos_mean                  5.862956e-03
# wtc_GenRpm_mean                  7.692995e-02
# wtc_HubLubGr_mean                         NaN
# wtc_IceDetec_mean                         NaN
# wtc_IMidBa_mean                           NaN
# wtc_IMidCa_mean                           NaN
# wtc_IMidAa_mean                           NaN
# wtc_MainSRpm_mean                7.692752e-02
# wtc_PitchRef_mean                         NaN
# wtc_PitchRef_BladeA_mean        -4.674119e-02
# wtc_PitchRef_BladeB_mean        -4.674485e-02
# wtc_PitchRef_BladeC_mean        -4.674063e-02
# wtc_PitcRefA_mean               -4.680818e-02
# wtc_PriAnemo_mean               -1.615750e-03
# wtc_PWMBa_mean                            NaN
# wtc_PWMCa_mean                            NaN
# wtc_PWMAa_mean                            NaN
# wtc_HubAnIn5_mean                         NaN
# wtc_HubAnIn6_mean                         NaN
# wtc_HubAnIn7_mean                         NaN
# wtc_NacHumid_mean                         NaN
# wtc_TwrHumid_mean               -1.925808e-02
# wtc_VisMeter_endvalue                     NaN
# wtc_PitcPosA_mean               -4.533663e-02
# wtc_PitcPosB_mean               -4.249868e-02
# wtc_PitcPosC_mean               -4.533603e-02
# wtc_PowerRef_endvalue            3.127438e-02
# wtc_ReactRef_endvalue                     NaN
# wtc_ScYawPos_mean                2.192029e-02
# wtc_PrWindSp_mean                1.077078e-01
# wtc_SeWindSp_mean                9.902938e-02
# wtc_AcWindSp_mean                1.089651e-01
# wtc_NacelPos_mean                5.862269e-03
# wtc_TetAnemo_mean                         NaN
# wtc_TetAnFrq_mean               -1.433139e-14
# wtc_TowerFrq_Frequenc_mean       1.919346e-02
# wtc_BoostAva_mean                1.000000e+00
#
# [38 rows x 38 columns]

# %%
# plot the correlation matricies
sbn.set(font_scale=2)
f, ax = plt.subplots(figsize=(20, 20)) #taken from Notebook 2: DataVisualization
sbn.heatmap(df_main.corr(), linewidths=0.5)
f.tight_layout()
plt.title("Correlation Heat Map of all Data", size=30)
# Out:
# Text(0.5,1,'Correlation Heat Map of all Data')

# %% [markdown]
# # To Do
# 1. Make a function that compares actual turbine power output and compare it to the expected output (power curve). Logan's Gap is Ref 18. Also, can I fit a power curve to this data? - **DONE**
# 2. Can I see if there are any other variables that impact power output?
# 3. Do some PCA analysis of weather data and compare that to the power curves.
# 4. Logan's Gap is WPP ID 14 (also look at the WTG data sets) #WTG is model 3 for Logan's Gap. So that is useful to know for comparison to expected.
# 5. Some basic descritptive statistics plots for some of the chosen variables

# %% [markdown]
# # Principal Component Analysis - What variables are the most important for explaining variance in power output?
# First we need to do a pre-processing pipeline. SKLEAN already has a tooln for this.
