# %%
import csv
import json
import pymongo
import pandas as pd

# %%
db_name = 'test'
collection_name = 'tblGrid'
csv_path = 'Documents/Pattern/tblGrid.csv'

# %%
client = pymongo.MongoClient('mongodb+srv://admin:OpsR3porting!@pattern-9xaut.mongodb.net/admin')
db = client[db_name]
col = db[collection_name]

# %%
data = pd.read_csv(csv_path)
data_json = json.loads(data.to_json(orient='records'))
# Out:
# C:\Users\Casiano\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (0,3,4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#col.remove()
col.insert(data_json)
# Out:
# C:\Users\Casiano\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\Casiano\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# [ObjectId('5ae66ed4a5d6d336e46d577b'),
#  ObjectId('5ae66ed4a5d6d336e46d577c'),
#  ObjectId('5ae66ed4a5d6d336e46d577d'),
#  ObjectId('5ae66ed4a5d6d336e46d577e'),
#  ObjectId('5ae66ed4a5d6d336e46d577f'),
#  ObjectId('5ae66ed4a5d6d336e46d5780'),
#  ObjectId('5ae66ed4a5d6d336e46d5781'),
#  ObjectId('5ae66ed4a5d6d336e46d5782'),
#  ObjectId('5ae66ed4a5d6d336e46d5783'),
#  ObjectId('5ae66ed4a5d6d336e46d5784'),
#  ObjectId('5ae66ed4a5d6d336e46d5785'),
#  ObjectId('5ae66ed4a5d6d336e46d5786'),
#  ObjectId('5ae66ed4a5d6d336e46d5787'),
#  ObjectId('5ae66ed4a5d6d336e46d5788'),
#  ObjectId('5ae66ed4a5d6d336e46d5789'),
# ...
